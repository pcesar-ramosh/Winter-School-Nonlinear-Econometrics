# %% [markdown]
# # Quantile Local Projections: Example

# %% [markdown]
# Useful Links:
#
# ---
#
# - https://romainlafarguette.github.io/codes/
# - https://github.com/romainlafarguette/quantileproj
# - https://github.com/suahjl/localprojections/tree/master
#
# ---

# %% [markdown]
# This notebook presents a (simple) application of quantile local projections
#
# It uses a Python package that I have written, quantileproj.py, also available in this Github folder (modules/). quantileproj is based on the Quantreg modules of statsmodels. The package also relies on my conditional quantile sampling module (https://github.com/romainlafarguette/cqsampling)
#
# The quantile uncrossing part is based on either:
#
# Chernozhukov et al. (2010) Quantile and Probability Curves Without Crossing, Econometrica
#
# Schmidt and Zhu (2016), Quantile Spacings: A Simple Method for the Joint Estimation of Multiple Quantiles Without Crossing
#
# Author: Romain Lafarguette, August 2020, https://github.com/romainlafarguette
#
# If you have any question, please contact me via Github

# %% [markdown]
# ## Preamble

# %%
# Main packages
import os, sys, importlib                               # System tools
import pandas as pd                                     # Dataframes
import numpy as np                                      # Numeric tools
import statsmodels.api as sm                            # Statistics

# Graphics
# %matplotlib inline
import matplotlib.pyplot as plt                         # Graphical package  
import seaborn as sns                                   # Graphical tools
plt.rcParams["figure.figsize"]=25,15 

# Local modules
import quantileproj; importlib.reload(quantileproj)     # Quantile projections
from quantileproj import QuantileProj

# %% [markdown]
# ## Parameters

# %%
quantile_l = list(np.arange(0.05, 1, 0.05)) # Every 5% quantiles (put less if you have "bad data")
horizon_l = [1, 2, 4, 8, 12] # 1Q - 3Y for quarterly data

# %% [markdown]
# ## Example data set (US macro data from statsmodels)

# %%
df = sm.datasets.macrodata.load_pandas().data.copy()

# Create a date index with end of quarter convention
dates_l = [f'{y:.0f}-Q{q:.0f}' for y,q in zip(df['year'], df['quarter'])]
df = df.set_index(pd.to_datetime(dates_l) + pd.offsets.QuarterEnd())

# Clean some variables
df['rgdp_growth'] = df['realgdp'].rolling(4).sum().pct_change(4)
df = df.rename(columns={'infl':'inflation', 'unemp':'unemployment'})
df['current_inflation'] = df['inflation'].copy() # To avoid name confusion dependent/regressor
print(df.describe())
print(df.tail())
# Out:
#               year     quarter       realgdp     realcons      realinv  \
# count   203.000000  203.000000    203.000000   203.000000   203.000000
# mean   1983.876847    2.492611   7221.171901  4825.293103  1012.863862
# std      14.686817    1.118563   3214.956044  2313.346192   585.102267
# min    1959.000000    1.000000   2710.349000  1707.400000   259.764000
# 25%    1971.000000    1.500000   4440.103500  2874.100000   519.147500
# 50%    1984.000000    2.000000   6559.594000  4299.900000   896.210000
# 75%    1996.500000    3.000000   9629.346500  6398.150000  1436.681500
# max    2009.000000    4.000000  13415.266000  9363.600000  2264.721000
#
#           realgovt       realdpi         cpi           m1    tbilrate  \
# count   203.000000    203.000000  203.000000   203.000000  203.000000
# mean    663.328640   5310.540887  105.075788   667.927586    5.311773
# std     140.863655   2423.515977   61.278878   455.346381    2.803071
# min     460.400000   1886.900000   28.980000   139.600000    0.120000
# 25%     527.959500   3276.950000   41.050000   228.650000    3.515000
# 50%     662.412000   4959.400000  104.100000   540.900000    5.010000
# 75%     773.049000   6977.850000  159.650000  1102.100000    6.665000
# max    1044.088000  10077.500000  218.610000  1673.900000   15.330000
#
#        unemployment         pop   inflation     realint  rgdp_growth  \
# count    203.000000  203.000000  203.000000  203.000000   196.000000
# mean       5.884729  239.724153    3.961330    1.336502     0.032276
# std        1.458574   37.390450    3.253216    2.668799     0.020692
# min        3.400000  177.146000   -8.790000   -6.790000    -0.028764
# 25%        4.900000  208.631000    2.270000   -0.085000     0.020512
# 50%        5.700000  236.348000    3.240000    1.340000     0.034978
# 75%        6.800000  271.721500    4.975000    2.630000     0.044834
# max       10.700000  308.013000   14.620000   10.950000     0.077487
#
#        current_inflation
# count         203.000000
# mean            3.961330
# std             3.253216
# min            -8.790000
# 25%             2.270000
# 50%             3.240000
# 75%             4.975000
# max            14.620000
#               year  quarter    realgdp  realcons   realinv  realgovt  realdpi  \
# 2008-09-30  2008.0      3.0  13324.600    9267.7  1990.693   991.551   9838.3
# 2008-12-31  2008.0      4.0  13141.920    9195.3  1857.661  1007.273   9920.4
# 2009-03-31  2009.0      1.0  12925.410    9209.2  1558.494   996.287   9926.4
# 2009-06-30  2009.0      2.0  12901.504    9189.0  1456.678  1023.528  10077.5
# 2009-09-30  2009.0      3.0  12990.341    9256.0  1486.398  1044.088  10040.6
#
#                 cpi      m1  tbilrate  unemployment      pop  inflation  \
# 2008-09-30  216.889  1474.7      1.17           6.0  305.270      -3.16
# 2008-12-31  212.174  1576.5      0.12           6.9  305.952      -8.79
# 2009-03-31  212.671  1592.8      0.22           8.1  306.547       0.94
# 2009-06-30  214.469  1653.6      0.18           9.2  307.226       3.37
# 2009-09-30  216.385  1673.9      0.12           9.6  308.013       3.56
#
#             realint  rgdp_growth  current_inflation
# 2008-09-30     4.33     0.015418              -3.16
# 2008-12-31     8.91     0.004384              -8.79
# 2009-03-31    -0.71    -0.008933               0.94
# 2009-06-30    -3.19    -0.022452               3.37
# 2009-09-30    -3.44    -0.028764               3.56
# C:\Users\paulo.ramos\AppData\Local\Temp\ipykernel_28824\126914098.py:5: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df = df.set_index(pd.to_datetime(dates_l) + pd.offsets.QuarterEnd())

# %% [markdown]
# ## Quantile model specification and fit

# %%
dependent = 'inflation'
regressors_l = ['current_inflation', 'rgdp_growth', 'unemployment', 'realint']

qr = QuantileProj(dependent, regressors_l, df, horizon_l)

qr_fit = qr.fit(quantile_l=quantile_l, alpha=0.05)
# Out:
# 7 missing obs on depvar and indvar
# 95 quantile regressions estimated for 5 horizons and 19 quantiles

# %% [markdown]
# ### All the coefficients, tstats, pvalues and R2 are packaged into a large dataframe

# %%
qr_fit.coeffs
# Out:
#                     tau  horizon      coeff      tval      pval   lower_ci  \
# Intercept          0.05        1   0.841561  0.499083  0.618298  -2.484546
# current_inflation  0.05        1   0.498922  4.931470  0.000002   0.299359
# rgdp_growth        0.05        1   3.799437  0.227499  0.820280 -29.143480
# unemployment       0.05        1  -0.502487 -2.557945  0.011309  -0.889973
# realint            0.05        1   0.464137  2.650024  0.008727   0.118660
# ...                 ...      ...        ...       ...       ...        ...
# Intercept          0.95       12   3.532466  1.093881  0.275477  -2.839924
# current_inflation  0.95       12  -0.327144 -2.283086  0.023601  -0.609899
# rgdp_growth        0.95       12 -14.588670 -0.449995  0.653258 -78.562487
# unemployment       0.95       12   1.527607  3.294593  0.001188   0.612642
# realint            0.95       12  -0.808226 -3.569373  0.000459  -1.255049
#
#                     upper_ci  pseudo_r2
# Intercept           4.167669   0.087149
# current_inflation   0.698485   0.087149
# rgdp_growth        36.742354   0.087149
# unemployment       -0.115000   0.087149
# realint             0.809614   0.087149
# ...                      ...        ...
# Intercept           9.904856   0.214528
# current_inflation  -0.044389   0.214528
# rgdp_growth        49.385147   0.214528
# unemployment        2.442571   0.214528
# realint            -0.361403   0.214528
#
# [475 rows x 8 columns]

# %% [markdown]
# ## Local projections based on a conditioning frame

# %%
# Design a conditioning frame (here last observation for instance)
cond_frame = df.loc[[max(df.index)], regressors_l].copy()
qr_proj = qr_fit.proj(cond_frame)

# %% [markdown]
# ### The fitted conditional quantiles are available in the object directly, with the asymptotics and sampled statistics

# %%
qr_proj.cond_quant
# Out:
#                            conditioning  horizon   tau  \
# conditioning horizon tau
# 0            1       0.05             0        1  0.05
#                      0.10             0        1  0.10
#                      0.15             0        1  0.15
#                      0.20             0        1  0.20
#                      0.25             0        1  0.25
# ...                                 ...      ...   ...
#              12      0.75             0       12  0.75
#                      0.80             0       12  0.80
#                      0.85             0       12  0.85
#                      0.90             0       12  0.90
#                      0.95             0       12  0.95
#
#                            conditional_quantile_mean  \
# conditioning horizon tau
# 0            1       0.05                  -3.912063
#                      0.10                  -0.016468
#                      0.15                   0.838409
#                      0.20                   1.482563
#                      0.25                   1.648238
# ...                                              ...
#              12      0.75                  10.882492
#                      0.80                  10.988227
#                      0.85                  12.846346
#                      0.90                  18.434627
#                      0.95                  20.232781
#
#                            conditional_quantile_mean_se  \
# conditioning horizon tau
# 0            1       0.05                      1.260987
#                      0.10                      1.033498
#                      0.15                      0.848262
#                      0.20                      0.850673
#                      0.25                      0.736804
# ...                                                 ...
#              12      0.75                      1.411929
#                      0.80                      1.556833
#                      0.85                      1.754242
#                      0.90                      2.027135
#                      0.95                      2.115421
#
#                            conditional_quantile_mean_ci_lower  \
# conditioning horizon tau
# 0            1       0.05                           -6.399396
#                      0.10                           -2.055072
#                      0.15                           -0.834812
#                      0.20                           -0.195413
#                      0.25                            0.194872
# ...                                                       ...
#              12      0.75                            8.096324
#                      0.80                            7.916120
#                      0.85                            9.384691
#                      0.90                           14.434470
#                      0.95                           16.058410
#
#                            conditional_quantile_mean_ci_upper  \
# conditioning horizon tau
# 0            1       0.05                           -1.424731
#                      0.10                            2.022137
#                      0.15                            2.511630
#                      0.20                            3.160540
#                      0.25                            3.101605
# ...                                                       ...
#              12      0.75                           13.668660
#                      0.80                           14.060335
#                      0.85                           16.308001
#                      0.90                           22.434784
#                      0.95                           24.407152
#
#                            conditional_quantile_obs_ci_lower  \
# conditioning horizon tau
# 0            1       0.05                          -7.086601
#                      0.10                          -2.853152
#                      0.15                          -1.748198
#                      0.20                          -1.107123
#                      0.25                          -0.801893
# ...                                                      ...
#              12      0.75                           7.468306
#                      0.80                           7.336957
#                      0.85                           8.861752
#                      0.90                          13.974225
#                      0.95                          15.615497
#
#                            conditional_quantile_obs_ci_upper
# conditioning horizon tau
# 0            1       0.05                          -0.737526
#                      0.10                           2.820216
#                      0.15                           3.425016
#                      0.20                           4.072249
#                      0.25                           4.098369
# ...                                                      ...
#              12      0.75                          14.296678
#                      0.80                          14.639498
#                      0.85                          16.830940
#                      0.90                          22.895029
#                      0.95                          24.850065
#
# [95 rows x 9 columns]

# %% [markdown]
# ### Plot the quantile coefficients and R2

# %%
label_d = {'rgdp_growth': 'Real GDP growth',
           'unemployment': 'Unemployment',
           'realint': 'Real interest rate'}

sns.set(style='white', font_scale=3, palette='deep', font='Arial') # Style
qr_fit.plot.coeffs_grid(horizon=1, label_d=label_d)
plt.subplots_adjust(hspace=0.4, wspace=0.4)
plt.show()

# %% [markdown]
# ### Term structure plots

# %%
sns.set(style='white', font_scale=3, palette='deep', font='Arial') # Style
qr_fit.plot.term_structure(variable='realint', title='Term structure of real interest rate at different horizons')
plt.subplots_adjust(hspace=0.4, wspace=0.4)
plt.show()

# %%
sns.set(style='white', font_scale=3, palette='deep', font='Arial') # Style
qr_fit.plot.term_coefficients(variable='realint', tau_l=[0.05, 0.25, 0.5, 0.75, 0.95], 
                              title='Term Quantile Coefficients for Real Interest Rate, at 5% confidence')
plt.subplots_adjust(hspace=0.5, wspace=0.4)
plt.show()

# %% [markdown]
# ### Conditional quantiles plot (fitted from quantile regressions)

# %%
sns.set(style='white', font_scale=4, palette='deep', font='Arial') # Style
qr_proj.plot.fitted_quantile(quantile=0.5, ylabel='percentage points', legendfont=20)
plt.show()

# %%
import numpy as np
np.float = float  # Solución temporal para código antiguo

# %% [markdown]
# ### Fan chart (based on resampled conditional quantiles)

# %%
sns.set(style='white', font_scale=4, palette='deep', font='Arial') # Style
qr_proj.plot.fan_chart(title='Inflation fan chart up to a 3-year horizon', ylabel='percentage points', 
                       len_sample=10000, seed=18041202)
plt.show()

# %% [markdown]
# ### Simulation and multi-conditioning sampling

# %%
# Expand the conditioning frame by generating shocks on the real interest rate
sim_frame_l = list()
for int_shock in np.arange(0, 3.1, 0.1):
    sim_frame = cond_frame.copy()
    sim_frame['realint'] = cond_frame['realint'].copy() + int_shock
    sim_frame_l.append(sim_frame)

dsim = pd.concat(sim_frame_l)

# Sample from the conditioning frame
multi_sample = qr_fit.proj(dsim).sample(seed=18021202) 

idx_d = {k:round(v,2) for k,v in enumerate(np.arange(0, 3.1, 0.1))}
multi_sample['realint_shock'] = multi_sample['conditioning'].map(idx_d)
multi_sample
# Out:
#      conditioning  horizon  inflation  realint_shock
# 0               0        1   3.659570            0.0
# 1               0        1  -3.450184            0.0
# 2               0        1   1.998899            0.0
# 3               0        1   2.498965            0.0
# 4               0        1   3.399798            0.0
# ..            ...      ...        ...            ...
# 995            30       12   7.847219            3.0
# 996            30       12   2.515985            3.0
# 997            30       12   3.297279            3.0
# 998            30       12   1.152165            3.0
# 999            30       12   2.829885            3.0
#
# [155000 rows x 4 columns]

# %%
# --- Compute quantiles of inflation for each real interest rate shock at horizon = 1
ql = [0.05, 0.25, 0.5, 0.75, 0.95]

# Filtrar horizonte
df_temp = multi_sample.loc[multi_sample['horizon'] == 1, :]

# Calcular los cuantiles y convertir correctamente a DataFrame
dqm = df_temp.groupby('realint_shock')['inflation'].quantile(ql).reset_index()

# Renombrar columnas
dqm.columns = ['realint_shock', 'tau', 'condquant']

# (Opcional) si necesitas mantener el nombre 'conditioning' para compatibilidad
dqm['conditioning'] = 'realint_shock'

# Reordenar columnas si quieres
dqmf = dqm[['conditioning', 'tau', 'realint_shock', 'condquant']]

# %%
fig, ax = plt.subplots()
for tau in sorted(set(dqmf['tau'])):
    dd = dqmf.loc[dqmf['tau']==tau, :].copy()
    ax.plot(dd['realint_shock'], dd['condquant'], label=tau)

ax.legend()
ax.set_xlabel('Real interest shock')
ax.set_ylabel('Inflation')
ax.set_title('Linear Impact of a Real Interest Rate Shock on Inflation \n'
             'At different quantiles at horizon 1')    
plt.show()
plt.close('all')

# %% [markdown]
# #### The file ends here
